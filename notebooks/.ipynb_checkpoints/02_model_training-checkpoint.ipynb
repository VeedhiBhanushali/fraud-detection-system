# %%
import pandas as pd
import xgboost as xgb
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report, accuracy_score
import joblib
from imblearn.over_sampling import SMOTE  # Import SMOTE

# Load processed data
train_df = pd.read_csv('../data/train_processed_transactions.csv')
val_df = pd.read_csv('../data/val_processed_transactions.csv')
test_df = pd.read_csv('../data/test_processed_transactions.csv')

# Define feature names
feature_names = ['Amount', 'hour', 'risk_score']

X_train, y_train = train_df[feature_names], train_df['Class']
X_val, y_val = val_df[feature_names], val_df['Class']
X_test, y_test = test_df[feature_names], test_df['Class']

### Apply SMOTE to Balance Dataset ###
smote = SMOTE(sampling_strategy=0.1, random_state=42)  # Create more fraud cases
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)  # Oversample minority class

# Convert DataFrames to DMatrix format for better performance
dtrain = xgb.DMatrix(X_train_smote, label=y_train_smote)
dval = xgb.DMatrix(X_val, label=y_val)
dtest = xgb.DMatrix(X_test)

# Define XGBoost parameters
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'max_depth': 5,
    'learning_rate': 0.3,
}

# Train XGBoost Model with early stopping
xgb_model = xgb.train(
    params, 
    dtrain, 
    num_boost_round=200, 
    evals=[(dval, 'validation')], 
    early_stopping_rounds=10
)

# Predict with trained model
xgb_preds = xgb_model.predict(dtest)
xgb_preds = (xgb_preds > 0.5).astype(int)  # Convert probabilities to binary predictions

# Evaluate models
xgb_accuracy = accuracy_score(y_test, xgb_preds)
print("XGBoost Accuracy:", xgb_accuracy)
print("Classification Report (XGBoost):\n", classification_report(y_test, xgb_preds))

# Save models
joblib.dump(xgb_model, '../src/xgb_model.pkl')

print("Model training complete. Models saved.")
# Out:
# [0]	validation-logloss:0.15238
# [1]	validation-logloss:0.13201
# [2]	validation-logloss:0.11722
# [3]	validation-logloss:0.10665
# [4]	validation-logloss:0.09877
# [5]	validation-logloss:0.09288
# [6]	validation-logloss:0.08872
# [7]	validation-logloss:0.08498
# [8]	validation-logloss:0.08213
# [9]	validation-logloss:0.07991
# [10]	validation-logloss:0.07841
# [11]	validation-logloss:0.07692
# [12]	validation-logloss:0.07604
# [13]	validation-logloss:0.07523
# [14]	validation-logloss:0.07451
# [15]	validation-logloss:0.07359
# [16]	validation-logloss:0.07291
# [17]	validation-logloss:0.07250
# [18]	validation-logloss:0.07204
# [19]	validation-logloss:0.07165
# [20]	validation-logloss:0.07149
# [21]	validation-logloss:0.07109
# [22]	validation-logloss:0.07067
# [23]	validation-logloss:0.07022
# [24]	validation-logloss:0.06999
# [25]	validation-logloss:0.06963
# [26]	validation-logloss:0.06922
# [27]	validation-logloss:0.06890
# [28]	validation-logloss:0.06849
# [29]	validation-logloss:0.06796
# [30]	validation-logloss:0.06775
# [31]	validation-logloss:0.06754
# [32]	validation-logloss:0.06731
# [33]	validation-logloss:0.06716
# [34]	validation-logloss:0.06698
# [35]	validation-logloss:0.06683
# [36]	validation-logloss:0.06666
# [37]	validation-logloss:0.06653
# [38]	validation-logloss:0.06644
# [39]	validation-logloss:0.06630
# [40]	validation-logloss:0.06634
# [41]	validation-logloss:0.06633
# [42]	validation-logloss:0.06624
# [43]	validation-logloss:0.06592
# [44]	validation-logloss:0.06553
# [45]	validation-logloss:0.06534
# [46]	validation-logloss:0.06517
# [47]	validation-logloss:0.06514
# [48]	validation-logloss:0.06500
# [49]	validation-logloss:0.06492
# [50]	validation-logloss:0.06472
# [51]	validation-logloss:0.06463
# [52]	validation-logloss:0.06443
# [53]	validation-logloss:0.06437
# [54]	validation-logloss:0.06412
# [55]	validation-logloss:0.06411
# [56]	validation-logloss:0.06409
# [57]	validation-logloss:0.06393
# [58]	validation-logloss:0.06382
# [59]	validation-logloss:0.06377
# [60]	validation-logloss:0.06357
# [61]	validation-logloss:0.06350
# [62]	validation-logloss:0.06342
# [63]	validation-logloss:0.06321
# [64]	validation-logloss:0.06304
# [65]	validation-logloss:0.06300
# [66]	validation-logloss:0.06297
# [67]	validation-logloss:0.06290
# [68]	validation-logloss:0.06290
# [69]	validation-logloss:0.06277
# [70]	validation-logloss:0.06274
# [71]	validation-logloss:0.06269
# [72]	validation-logloss:0.06260
# [73]	validation-logloss:0.06256
# [74]	validation-logloss:0.06253
# [75]	validation-logloss:0.06246
# [76]	validation-logloss:0.06243
# [77]	validation-logloss:0.06234
# [78]	validation-logloss:0.06230
# [79]	validation-logloss:0.06225
# [80]	validation-logloss:0.06222
# [81]	validation-logloss:0.06209
# [82]	validation-logloss:0.06204
# [83]	validation-logloss:0.06201
# [84]	validation-logloss:0.06189
# [85]	validation-logloss:0.06187
# [86]	validation-logloss:0.06187
# [87]	validation-logloss:0.06179
# [88]	validation-logloss:0.06171
# [89]	validation-logloss:0.06165
# [90]	validation-logloss:0.06158
# [91]	validation-logloss:0.06159
# [92]	validation-logloss:0.06155
# [93]	validation-logloss:0.06148
# [94]	validation-logloss:0.06146
# [95]	validation-logloss:0.06143
# [96]	validation-logloss:0.06139
# [97]	validation-logloss:0.06132
# [98]	validation-logloss:0.06133
# [99]	validation-logloss:0.06127
# [100]	validation-logloss:0.06119
# [101]	validation-logloss:0.06123
# [102]	validation-logloss:0.06123
# [103]	validation-logloss:0.06122
# [104]	validation-logloss:0.06119
# [105]	validation-logloss:0.06116
# [106]	validation-logloss:0.06111
# [107]	validation-logloss:0.06109
# [108]	validation-logloss:0.06105
# [109]	validation-logloss:0.06105
# [110]	validation-logloss:0.06103
# [111]	validation-logloss:0.06099
# [112]	validation-logloss:0.06095
# [113]	validation-logloss:0.06096
# [114]	validation-logloss:0.06093
# [115]	validation-logloss:0.06093
# [116]	validation-logloss:0.06090
# [117]	validation-logloss:0.06087
# [118]	validation-logloss:0.06083
# [119]	validation-logloss:0.06080
# [120]	validation-logloss:0.06073
# [121]	validation-logloss:0.06074
# [122]	validation-logloss:0.06066
# [123]	validation-logloss:0.06066
# [124]	validation-logloss:0.06062
# [125]	validation-logloss:0.06060
# [126]	validation-logloss:0.06058
# [127]	validation-logloss:0.06053
# [128]	validation-logloss:0.06055
# [129]	validation-logloss:0.06050
# [130]	validation-logloss:0.06049
# [131]	validation-logloss:0.06050
# [132]	validation-logloss:0.06047
# [133]	validation-logloss:0.06050
# [134]	validation-logloss:0.06048
# [135]	validation-logloss:0.06042
# [136]	validation-logloss:0.06044
# [137]	validation-logloss:0.06043
# [138]	validation-logloss:0.06040
# [139]	validation-logloss:0.06038
# [140]	validation-logloss:0.06038
# [141]	validation-logloss:0.06039
# [142]	validation-logloss:0.06038
# [143]	validation-logloss:0.06034
# [144]	validation-logloss:0.06031
# [145]	validation-logloss:0.06034
# [146]	validation-logloss:0.06034
# [147]	validation-logloss:0.06028
# [148]	validation-logloss:0.06023
# [149]	validation-logloss:0.06020
# [150]	validation-logloss:0.06019
# [151]	validation-logloss:0.06021
# [152]	validation-logloss:0.06018
# [153]	validation-logloss:0.06016
# [154]	validation-logloss:0.06014
# [155]	validation-logloss:0.06015
# [156]	validation-logloss:0.06013
# [157]	validation-logloss:0.06011
# [158]	validation-logloss:0.06011
# [159]	validation-logloss:0.06009
# [160]	validation-logloss:0.06008
# [161]	validation-logloss:0.06008
# [162]	validation-logloss:0.06004
# [163]	validation-logloss:0.06001
# [164]	validation-logloss:0.06000
# [165]	validation-logloss:0.06000
# [166]	validation-logloss:0.05999
# [167]	validation-logloss:0.05998
# [168]	validation-logloss:0.05996
# [169]	validation-logloss:0.05993
# [170]	validation-logloss:0.05994
# [171]	validation-logloss:0.05993
# [172]	validation-logloss:0.05992
# [173]	validation-logloss:0.05992
# [174]	validation-logloss:0.05992
# [175]	validation-logloss:0.05990
# [176]	validation-logloss:0.05990
# [177]	validation-logloss:0.05988
# [178]	validation-logloss:0.05987
# [179]	validation-logloss:0.05986
# [180]	validation-logloss:0.05985
# [181]	validation-logloss:0.05985
# [182]	validation-logloss:0.05984
# [183]	validation-logloss:0.05986
# [184]	validation-logloss:0.05983
# [185]	validation-logloss:0.05983
# [186]	validation-logloss:0.05980
# [187]	validation-logloss:0.05978
# [188]	validation-logloss:0.05978
# [189]	validation-logloss:0.05978
# [190]	validation-logloss:0.05978
# [191]	validation-logloss:0.05978
# [192]	validation-logloss:0.05977
# [193]	validation-logloss:0.05978
# [194]	validation-logloss:0.05978
# [195]	validation-logloss:0.05974
# [196]	validation-logloss:0.05973
# [197]	validation-logloss:0.05971
# [198]	validation-logloss:0.05970
# [199]	validation-logloss:0.05968
# XGBoost Accuracy: 0.9919713496559149
# Classification Report (XGBoost):
#                precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     42663
#            1       0.05      0.27      0.09        59
#
#     accuracy                           0.99     42722
#    macro avg       0.52      0.63      0.54     42722
# weighted avg       1.00      0.99      0.99     42722
#
# Model training complete. Models saved.
